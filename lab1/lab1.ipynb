# %% [markdown]
# # ECE 5470 Lab 1 Report
#
# ## by Rufei Ye

# %%
import numpy as np
from v4 import vx
from v4 import vd

vd.dispmvx("ein.vx", size=0.3, capt="ein.vx")
# Out:
# ein.vx
# <scaled size: (256 x 256) >

# %% [markdown]
# ### A. General Image Manipulation
# 1.	What are the pixel coordinates of Albert’s right eye?
#   X = 106.52, Y = 101.20
# 2.	How did you make this measurement?
#    1. I zoomed the image to 19 times and centered the right pupil in the field of view.
#    2. I used the "Probe." tool and dragged my mouse on the center of the pupil of the right eye.
#    3. The pixel coordinates appeared in the upper left corner of the image.
# 3.	What is the width of Albert’s mustache?
#    45.82mm
# 4.	What are the main issues in making distance measurements on images? Consider and comment on the following: (a) Mouse Control, (b) Feature visibility, (c) Image Size, (e) Question ambiguity.
#    1. Mouse control: After activating the "Length" tool, I used mouse to drew a line and moved it to measure the width. If I cannot control the mouse well, such as failing to zoom the image, it will be terrible to drew lines.
#    2. Feature visibility: This is very important. Comparing the left and right halves of the picture, the simple line on the right helps me better confirm the extent of the mustache. But the mustache on the left is a bit blurry and hard to define.
#    3. Image Size: In order to see the image clearly, I zoomed the image to 10 times.
#    4. Question ambiguity: It is really important. I think the width of the mustache is a vague concept, I'm not sure if it's a horizontal or vertical measurement, a bread or a mustache…… Finally I chose to measure the horizontal length of his mustache.

# %% [markdown]
# ### B. Grey Level Image manipulation
#
# 1.	Window=2 Level=128. what type of image do you observe? what is a useful purpose for this setting?
#
#    The type of image is Binary image.
#    The image consists almost exclusively of black and white.Binary monochrome images highlight some of the characteristics of the picture and make it easier for the computer to perform image processing.
# 2.	Window=512 Level=128. what is the range of displayed image pixel values with this setting?
#
#     window = upper bound -lower bound; level = (upper bound + lower bound) / 2
#
#     -128~384
# 3.	Window=512, Level=0. what is the range of displayed image pixel values with this setting?
#
#     -256~256

# %% [markdown]
# ### C. Image File Inspection
# 1.	What is the size (dimensions) of the image in the file girl-grey.vx? How did you find this?
#
#    Size: 256 x 256. I found it by using the commmand "vqfile -q -s girl-grey.vx" in the terminal.
# 2.  What is the type of the pixels of the image in the file girl-grey.vx? How did you find this?
#
#    Pixel Type: byte. I found it by using the commmand "vqfile -q -s girl-grey.vx" in the terminal.
# 3. On what date was the file girl-grey.vx created? How did you find this?
#
#    It created on Fri Aug 12 00:48:46 2022. I found it by using the commmand "vls -l girl-grey.vx" in the terminal.
# 4. What is the mean pixel value in the iamge in girl-grey.vx? How did you find this?
#
#    The mean pixel value in the image is 73.565. I found it by using the commmand "vps girl-grey.vx" in the terminal.

# %%
# Examples of using the python utilites
# 1. Run this cell to import the image and then
# display the histogram usign the vd.dhist function
img=vx.Vx('girl-grey.vx')
vd.dhist(img, capt='Histogram of girl-grey.vx')
# Out:
# Histogram of girl-grey.vx

# %%
# 1. Run this cell to assess and present information about the image
# using the utility vx.vxsh and linux commands
exec (vx.vxsh( 'vps girl-grey.vx' ))
print (vx.vxshreturn())
# Out:
#  Global Statistics Summary
#
# 1 images in file    256 x 256 (0,0)
#
# 65536      (65536     ) number of pixels
# 254        (254       ) maximum pixel value
# 1          (1         ) minimum pixel value
# 253        (253       ) range
# 73.565     (73.565    ) mean pixel value
# 1816.53    (1816.53   ) variance
# 42.6207    (42.6207   ) standard deviation
# 0.917956   (0.917956  ) skewness
# 3.72903    (3.72903   ) kurtosis

# %% [markdown]
# ### D. Image Set Display, Pixel Quantization
#
#
# 1.	What does the girl image sequence show?
#
#    Variation of images in different grayscale and bpp.The visual quality changes.
# 2.	What do the image parameters printed in the caption of the image mean?
#
#    Grey reflects the degree of gray scale image. BPP: Bites per pixel is the number of bits used to store each pixel, which is also used to measure the resolution of an image.
# 3.	At what quantization does degradation in image quality become noticeable?
#
#    grey =42, bpp=6
# 4.	What is the implication of this observation for image display design? Comment on the number of gray levels you would include in a product for general use and why?
#
#    64.Because in the case of constant bpp, when the gray scale changed from 64 to 42, my naked eye noticed the change of the image quality.
# 5.	Many home theater systems claim to have a 4000 to 1 contrast ratio or (much) greater. Assuming that this is possible by the image encoding methods used, how is such a large range useful given human visual system limitations?
#
#   The eye is not a standard device like a sensor. It has a dynamic range. Although it has limits, it changes according to different light and brightness. Moreover, higher contrast and grayscale performance is also the basis for LCD TVs to have more color capability, and the human visal system will perceive this.

# %% [markdown]
# ### E. Terminal command and log enhancement
# 1.	What does the vmath command do?
#
#   To the image " girl-grey.vx",compute the logarithm of all pixel values, and set the range of the output pixels from lval to hval. Save and output these changes in a new file " girl-log.vx".
# 2.	How does the vmath operation affect the visibility of image features?
# Are some parts of the image easier to see after the log transform?
# Is it possible to see more or less detail after the transform?
#
#    Vmath performs a function or a set of functions on each pixel of the image data file. After the log transform, the image becomes brighter.The brightness of the lower (darker) grayscale parts increased. The place where was black or deep grey became clearer, but the details on the girl's face lost, such as moles and some wrinkles.
# 3.	If more detail is visible, how is this possible? (consider your answer to question 2) (think carefully)
#
#    Since the logarithmic curve has a large slope in regions with lower pixel values and a smaller slope in regions with higher pixel values, the image will have increased contrast in the darker regions after the logarithmic transformation, so it will be possible to enhance the dark details of the image.

# %% [markdown]
# ### F. Large Image Display

# %%
xray=vx.Vx('xray.vs')
vd.dispmvx(xray, capt='xray.vs logo', size=0.3)
# Out:
# xray.vs logo
# <scaled size: (2048 x 2048) >

# %% [markdown]
# 1.	What is the size of the x-ray image?
#
#    2048x2048
# 2.	What are the window settings?
#
#    Window = 1756, Level = 3144
# 3.	Which interpolation method is the best and why?
#
#    Cubic spline interpolation. This method fits a different cubic polynomial between each pair of data points for curves, or between sets of three points for surfaces. High-order interpolation is better than low-order interpolation when the magnification is relatively high.

# %%
# Exampe display of image sequence image and histogram
grls=vx.Vx('girl-seq.vx')
vd.dispmvx(grls.i[2], capt='girl-seq.vx image 3', size=0.5 )
vd.dhist(grls.i[2], capt='Histogram of girl-seq.vx image 3' )
# Out:
# girl-seq.vx image 3
# <scaled size: (256 x 256) >
# Histogram of girl-seq.vx image 3

# %% [markdown]
# 4. How do you think the images in girl-seq.vx were created?
#
#    It used the interpolation method.
# 5. How do you explain the differences between the histograms of girl-grey.vx and girl-seq.vx image 3 ?
#
#    Interpolation made up space for blank pixels.

# %% [markdown]
# ### G. Segmentation Using Thresholding
#
#
# 1.	What is the best threshold for the facsimile image?
#
#     level = 218
# 2.	What is your criterion for best threshold?
#
#     Every letter is complete and clear, and there is no other noise
# 3.	What is the best threshold for the map image?
#
#     level = 85
# 4.	What is your criterion for best threshold?
#
#     Every road is clearly visible and not obscured by black shadows around the map.
# 5.	What is the problem in thresholding the map image?
#
#     If set a high level, black shadows around the map appear and cover the road lines.
# 6.	How might you get a better result on the map image? (That is, what kind of processing operations might improve the result?)
#
#    Set the "Window" value higher.

# %% [markdown]
# ### H.   Edge Detection
# </span>
# <img src="caboose.png" width="100px" >
#
# 1.	Are all the edges detected by vedge?
#
#     No.
# 2.	Can you improve the result? (by using different options)
#
#    I tried to changed the "th=" parameter and added "-s/-r/-i" to the verge commands.After several experiments, I found that The smaller the parameter, the clearer the  verge. In my view, when th = 10 and using the roberts cross edge operator, all the edges of the subject are detected.
# 3.	What is an edge? (a) provide a definition for an edge:
#
#    Edge is the outline of the image subject, which can distinguish the subject from the background.
# 4.	Describe what you mean by edges in the context of the caboose image.
#
#    Contour of trolley and track.
# 5. In a code cell use the a python utility program to display the caboose input image and the edge image result side by side.

# %%
vd.dispmvx("caboose.vx","r0ecaboose.vx", size=1.0,capt='caboose input image and the edge image result')
# Out:
# caboose input image and the edge image result
# <scaled size: (480 x 640) (480 x 640) >
