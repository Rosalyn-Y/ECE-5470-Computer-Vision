# %%
import numpy as np
from v4 import vx
from v4 import vd

# %%
exec(vx.vxsh('vtpeakpy d=10 mp.vx of=mpt.vx'))
vd.dispmvx('mp.vx','mpt.vx',size=0.75,  capt='result of vtpeakpy on mp.vx with d=10')
# Out:
# result of vtpeakpy on mp.vx with d=10
# <scaled size: (512 x 512) (512 x 512) >

# %%
d=10/50:maxbin= 172 nxtbin= 82 thresh= 83
d=100:没有区分度 全白

# %%
vd.dispvx('mph.png')
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7FCE49BA5990>

# %%
vd.dispmvx('nbh.png')
# Out:
# <scaled size: (300 x 400) >

# %%
exec(vx.vxsh('vtpeakpy d=20 nb.vx of=nbt.vx'))
vd.dispmvx('nb.vx','nbt.vx',size=0.75,  capt='result of vtpeakpy on nb.vx with d=5')
# Out:
# result of vtpeakpy on nb.vx with d=5
# <scaled size: (64 x 128) (64 x 128) >

# %%
maxbin= 139 nxtbin= 201 thresh= 140
d=5,d=20都是上述结果

# %%
vd.dispvx('maph.png')
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7FCE711528D0>

# %%
exec(vx.vxsh('vtpeakpy d=70 map of=mapt.vx'))
vd.dispmvx('map','mapt.vx',size=0.75,  capt='result of vtpeakpy on map with d=100')
# Out:
# result of vtpeakpy on map with d=100
# <scaled size: (512 x 512) (512 x 512) >

# %%
d=100: maxbin= 127 nxtbin= 27 thresh= 64
d=70: maxbin= 127 nxtbin= 35 thresh= 64
d=50: maxbin= 127 nxtbin= 178 thresh= 177 周围有黑圈

# %%
vd.dispmvx('facsimileh.png')
# Out:
# <scaled size: (300 x 400) >

# %%
exec(vx.vxsh('vtpeakpy d=5 facsimile of=facsimilet.vx'))
vd.dispmvx('facsimile','facsimilet.vx',size=0.75,  capt='result of vtpeakpy on map with d=5')
# Out:
# result of vtpeakpy on map with d=5
# <scaled size: (256 x 256) (256 x 256) >

# %%
d=5: maxbin= 240 nxtbin= 235 thresh= 235
d=10: maxbin= 240 nxtbin= 250 thresh= 250 black
d=50: maxbin= 240 nxtbin= 0 thresh= 1  white

# %%
vd.dispmvx('shtlh.png')
# Out:
# <scaled size: (300 x 400) >

# %%
exec(vx.vxsh('vtpeakpy d=50 shtl.vx of=shtlt.vx'))
vd.dispmvx('shtl.vx','shtlt.vx',size=0.75,  capt='result of vtpeakpy on shtl.vx with d=50')
# Out:
# result of vtpeakpy on shtl.vx with d=50
# <scaled size: (256 x 256) (256 x 256) >

# %%
maxbin= 148 nxtbin= 93 thresh= 112
