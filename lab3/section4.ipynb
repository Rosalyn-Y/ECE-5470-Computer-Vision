# %%
import numpy as np
from v4 import vx
from v4 import vd

# %% [markdown]
# range test

# %%
exec(vx.vxsh('vgrow test_range.vx of=test_range_vgrowr10.vx'))
vd.dispvx('test_range.vx')
vd.dispvx('test_range_vgrowr10.vx',size=0.75,  capt='default range=10')
# Out:
# <PIL.Image.Image image mode=L size=311x187 at 0x7FB10FF87D50>
# <PIL.Image.Image image mode=L size=311x187 at 0x7FB0ED849C10>
# default range=10

# %%
exec(vx.vxsh('vcmap lf=rand test_range_vgrowr10.vx of=co1.vx'))
exec(vx.vxsh('vccvt -i co1.vx of=conew1.vx'))
vd.dispmvx('conew1.vx')
# Out:
# <scaled size: (6 x 10) >

# %%
exec(vx.vxsh('vgrow test_range.vx of=test_range_vgrowr5.vx r=5'))
vd.dispvx('test_range.vx')
vd.dispvx('test_range_vgrowr5.vx',size=0.75,  capt='set range=5')
# Out:
# <PIL.Image.Image image mode=L size=311x187 at 0x7FB0ECAB3310>
# <PIL.Image.Image image mode=L size=311x187 at 0x7FB0ECAB3310>
# set range=5

# %%
exec(vx.vxsh('vcmap lf=rand test_range_vgrowr5.vx of=co2.vx'))
exec(vx.vxsh('vccvt -i co2.vx of=conew2.vx'))
vd.dispmvx('conew2.vx')
# Out:
# <scaled size: (6 x 10) >

# %% [markdown]
# -p test

# %%
exec(vx.vxsh('vgrow test_range.vx of=test_range_vgrowr5p.vx -p r=5'))
vd.dispvx('test_range.vx')
vd.dispvx('test_range_vgrowr5p.vx',size=0.75,  capt='default range=5,p')
# Out:
# <PIL.Image.Image image mode=L size=311x187 at 0x7FB10E99C050>
# <PIL.Image.Image image mode=L size=311x187 at 0x7FB0D6C43FD0>
# default range=5,p

# %%
exec(vx.vxsh('vcmap lf=rand test_range_vgrowr5p.vx of=co.vx'))
exec(vx.vxsh('vccvt -i co.vx of=conew3.vx'))
vd.dispmvx('conew3.vx')
# Out:
# <scaled size: (6 x 10) >

# %%
exec(vx.vxsh('vgrow nb.vx of=nb_vgrow.vx r=87 -p'))
vd.dispmvx('nb.vx','nb_vgrow.vx',size=0.75,  capt='r=87')
# Out:
# r=87
# <scaled size: (64 x 128) (64 x 128) >

# %%
exec(vx.vxsh('vgrow shtl.vx of=shtl_vgrow.vx r=5 -p'))
vd.dispmvx('shtl.vx','shtl_vgrow.vx',size=0.75,  capt='r=5')
# Out:
# r=5
# <scaled size: (256 x 256) (256 x 256) >

# %%
exec(vx.vxsh('vcmap lf=rand shtl_vgrow.vx of=coshtl.vx'))
exec(vx.vxsh('vccvt -i coshtl.vx of=coshtl1.vx'))
vd.dispmvx('coshtl1.vx')
# Out:
# <scaled size: (256 x 256) >

# %%
exec(vx.vxsh('vgrow edge.vx of=edge_vgrow.vx r=30'))
vd.dispmvx('edge.vx','edge_vgrow.vx',size=0.75,  capt='r=43')
# Out:
# r=43
# <scaled size: (256 x 256) (256 x 256) >

# %%
exec(vx.vxsh('vcmap lf=rand edge.vx of=edge_col.vx'))
exec(vx.vxsh('vccvt -i edge_col.vx of=edge_colnew.vx'))
vd.dispmvx('edge_colnew.vx')
# Out:
# <scaled size: (256 x 256) >

# %%
exec(vx.vxsh('vcmap lf=rand edge_vgrow.vx of=edge_co.vx'))
exec(vx.vxsh('vccvt -i edge_co.vx of=edge_conew.vx'))
vd.dispmvx('edge_conew.vx')
# Out:
# <scaled size: (256 x 256) >

# %% [markdown]
# more than 255 regions
