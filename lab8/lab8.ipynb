# %% [markdown]
# # ECE 5470 Lab 8 Report
#
#
# ## by Rufei Ye

# %%
from v4 import vd

# %% [markdown]
# ##  1. Model evaluation
#
#
# #### Model K1

# %% [markdown]
# Epoch 1/12
# 469/469 [==============================] - 386s 819ms/step - loss: 2.2971 - accuracy: 0.1374 - val_loss: 2.2587 - val_accuracy: 0.3995
# Epoch 2/12
# 469/469 [==============================] - 470s 1s/step - loss: 2.2532 - accuracy: 0.2570 - val_loss: 2.2006 - val_accuracy: 0.5670
# Epoch 3/12
# 469/469 [==============================] - 550s 1s/step - loss: 2.1959 - accuracy: 0.3606 - val_loss: 2.1223 - val_accuracy: 0.6387
# Epoch 4/12
# 469/469 [==============================] - 594s 1s/step - loss: 2.1197 - accuracy: 0.4365 - val_loss: 2.0148 - val_accuracy: 0.6778
# Epoch 5/12
# 469/469 [==============================] - 549s 1s/step - loss: 2.0151 - accuracy: 0.4918 - val_loss: 1.8679 - val_accuracy: 0.7013
# Epoch 6/12
# 469/469 [==============================] - 618s 1s/step - loss: 1.8721 - accuracy: 0.5379 - val_loss: 1.6810 - val_accuracy: 0.7286
# Epoch 7/12
# 469/469 [==============================] - 607s 1s/step - loss: 1.7021 - accuracy: 0.5756 - val_loss: 1.4695 - val_accuracy: 0.7574
# Epoch 8/12
# 469/469 [==============================] - 687s 1s/step - loss: 1.5229 - accuracy: 0.6067 - val_loss: 1.2644 - val_accuracy: 0.7760
# Epoch 9/12
# 469/469 [==============================] - 709s 2s/step - loss: 1.3562 - accuracy: 0.6353 - val_loss: 1.0881 - val_accuracy: 0.7947
# Epoch 10/12
# 469/469 [==============================] - 614s 1s/step - loss: 1.2224 - accuracy: 0.6559 - val_loss: 0.9496 - val_accuracy: 0.8093
# Epoch 11/12
# 469/469 [==============================] - 636s 1s/step - loss: 1.1139 - accuracy: 0.6774 - val_loss: 0.8437 - val_accuracy: 0.8190
# Epoch 12/12
# 469/469 [==============================] - 554s 1s/step - loss: 1.0211 - accuracy: 0.6969 - val_loss: 0.7628 - val_accuracy: 0.8292
#
# Time Elapsed: 6974.98306 seconds
# Test loss: 0.7627773284912109
# Test accuracy: 0.829200029373169
# Time Elapsed: 63.89487 seconds

# %%
from IPython.display import display
from PIL import Image
im = Image.open("K1-2.png")
print("Graphs of K1 Model")
display(im)
im = Image.open("K1-3.png")
display(im)
im = Image.open("K1-4.png")
display(im)
# Out:
# Graphs of K1 Model
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=386x278 at 0x7F6F8C1BBF10>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=386x278 at 0x7F6F8C1BBC10>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=323x280 at 0x7F6F8C1BB950>

# %% [markdown]
# Above are the results of the demonstration notebook ModelK1-Keras without modification. The test accuracy is 82.92%, while the test loss is 0.7628. The training accuracy of final epoch is 69.69%, while the training loss is 1.0211. The model K1 is time-consuming, but not performs well. The training accuracy is low, so it may need more epochs to train. From the plots of model accuracy and model loss, the training accuracy keeps rising and the loss keeps decreasing, which means the model is a little underfitting. And the confusion matrix vividly shows that most of the errors are in the confusion of numbers 2 and 5, 4 and 9.

# %% [markdown]
# #### Model P1

# %% [markdown]
# EPOCH [1/12]. Running Loss: 357.72 Progress: 42.67 %
# EPOCH [1/12]. Running Loss: 677.75 Progress: 85.33 %
# Train Avg. Loss: [1.5527] Acc: 0.791 on 60000.0 images
# Validating...
# Val Avg. Loss: [1.4614] Acc: 0.9475 on 10000.0 images
#
# EPOCH [2/12]. Running Loss: 306.51 Progress: 42.67 %
# EPOCH [2/12]. Running Loss: 610.07 Progress: 85.33 %
# Train Avg. Loss: [1.5173] Acc: 0.9416 on 60000.0 images
# Validating...
# Val Avg. Loss: [1.4612] Acc: 0.9688 on 10000.0 images
#
# EPOCH [3/12]. Running Loss: 300.87 Progress: 42.67 %
# EPOCH [3/12]. Running Loss: 601.09 Progress: 85.33 %
# Train Avg. Loss: [1.4833] Acc: 0.9599 on 60000.0 images
# Validating...
# Val Avg. Loss: [1.4612] Acc: 0.9775 on 10000.0 images
#
# EPOCH [4/12]. Running Loss: 298.83 Progress: 42.67 %
# EPOCH [4/12]. Running Loss: 597.63 Progress: 85.33 %
# Train Avg. Loss: [1.4805] Acc: 0.9685 on 60000.0 images
# Validating...
# Val Avg. Loss: [1.4612] Acc: 0.9809 on 10000.0 images
#
# EPOCH [5/12]. Running Loss: 298.02 Progress: 42.67 %
# EPOCH [5/12]. Running Loss: 596.0 Progress: 85.33 %
# Train Avg. Loss: [1.469] Acc: 0.9721 on 60000.0 images
# Validating...
# Val Avg. Loss: [1.4612] Acc: 0.9831 on 10000.0 images
#
# EPOCH [6/12]. Running Loss: 297.56 Progress: 42.67 %
# EPOCH [6/12]. Running Loss: 594.89 Progress: 85.33 %
# Train Avg. Loss: [1.4918] Acc: 0.9752 on 60000.0 images
# Validating...
# Val Avg. Loss: [1.4612] Acc: 0.9841 on 10000.0 images
#
# EPOCH [7/12]. Running Loss: 297.22 Progress: 42.67 %
# EPOCH [7/12]. Running Loss: 594.13 Progress: 85.33 %
# Train Avg. Loss: [1.498] Acc: 0.9766 on 60000.0 images
# Validating...
# Val Avg. Loss: [1.4612] Acc: 0.9851 on 10000.0 images
#
# EPOCH [8/12]. Running Loss: 296.75 Progress: 42.67 %
# EPOCH [8/12]. Running Loss: 593.69 Progress: 85.33 %
# Train Avg. Loss: [1.4612] Acc: 0.9776 on 60000.0 images
# Validating...
# Val Avg. Loss: [1.4612] Acc: 0.9856 on 10000.0 images
#
# EPOCH [9/12]. Running Loss: 296.61 Progress: 42.67 %
# EPOCH [9/12]. Running Loss: 592.81 Progress: 85.33 %
# Train Avg. Loss: [1.4899] Acc: 0.9797 on 60000.0 images
# Validating...
# Val Avg. Loss: [1.4612] Acc: 0.9851 on 10000.0 images
#
# EPOCH [10/12]. Running Loss: 296.22 Progress: 42.67 %
# EPOCH [10/12]. Running Loss: 592.31 Progress: 85.33 %
# Train Avg. Loss: [1.4718] Acc: 0.9803 on 60000.0 images
# Validating...
# Val Avg. Loss: [1.4612] Acc: 0.9849 on 10000.0 images
#
# EPOCH [11/12]. Running Loss: 296.09 Progress: 42.67 %
# EPOCH [11/12]. Running Loss: 591.88 Progress: 85.33 %
# Train Avg. Loss: [1.4715] Acc: 0.9824 on 60000.0 images
# Validating...
# Val Avg. Loss: [1.4612] Acc: 0.9871 on 10000.0 images
#
# EPOCH [12/12]. Running Loss: 295.76 Progress: 42.67 %
# EPOCH [12/12]. Running Loss: 591.48 Progress: 85.33 %
# Train Avg. Loss: [1.4819] Acc: 0.9828 on 60000.0 images
# Validating...
# Val Avg. Loss: [1.4612] Acc: 0.9881 on 10000.0 images
#
# Time Elapsed: 2298.04494 seconds
#
# Test Accuracy of the model on the 10000 test images: 98.81 %
# Time Elapsed: 3.698109 seconds

# %%
im = Image.open("P1-2.png")
print("Graphs of P1 Model ")
display(im)
im = Image.open("P1-4.png")
display(im)
# Out:
# Graphs of P1 Model
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=674x336 at 0x7F6F8C1C5C90>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=323x280 at 0x7F6F8C1C5890>

# %% [markdown]
# Above are the results of implementing the keras model, ModelK1, in pytorch. The test accuracy is 98.81%, while the test loss is 1.4612. The training accuracy of final epoch is 98.28%, while the training loss is 1.4819. Compared to model P1, the hyperparameters and network layers are modified in order to implement the same keras model in pytorch.
#
# The model P1 is less time-consuming than K1, and performs better. Both the training accuracy and the test accuracy is high. From the plots of model accuracy and model loss, the training accuracy gradually increases until it stabilizes while the loss fluctuates up and down. The model P1 does not underfit.
#
# There may be some differences in the way the model is trained between Pytorch and Keras, which causes the accuracy improvement in performance. And the confusion matrix vividly shows that there's no concentrated errors.

# %% [markdown]
# #### Model K2

# %% [markdown]
# Epoch 1/6
# 600/600 [==============================] - 292s 484ms/step - loss: 0.9208 - accuracy: 0.7267 - val_loss: 0.2058 - val_accuracy: 0.9482
# Epoch 2/6
# 600/600 [==============================] - 285s 475ms/step - loss: 0.1461 - accuracy: 0.9579 - val_loss: 0.0928 - val_accuracy: 0.9726
# Epoch 3/6
# 600/600 [==============================] - 286s 476ms/step - loss: 0.0931 - accuracy: 0.9727 - val_loss: 0.0673 - val_accuracy: 0.9799
# Epoch 4/6
# 600/600 [==============================] - 286s 477ms/step - loss: 0.0624 - accuracy: 0.9823 - val_loss: 0.0556 - val_accuracy: 0.9831
# Epoch 5/6
# 600/600 [==============================] - 289s 481ms/step - loss: 0.0499 - accuracy: 0.9860 - val_loss: 0.0465 - val_accuracy: 0.9852
# Epoch 6/6
# 600/600 [==============================] - 209s 348ms/step - loss: 0.0402 - accuracy: 0.9881 - val_loss: 0.0420 - val_accuracy: 0.9855
# Time Elapsed: 1647.64295 seconds
# Test loss: 0.04198489710688591
# Test accuracy: 0.9854999780654907
# Time Elapsed: 3.830423 seconds

# %%
im = Image.open("K2-2.png")
print("Graphs of K2 Model ")
display(im)
im = Image.open("K2-3.png")
display(im)
im = Image.open("K2-4.png")
display(im)
# Out:
# Graphs of K2 Model
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=392x278 at 0x7F6F8C1C5B90>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=386x278 at 0x7F6F8C1C5AD0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=323x280 at 0x7F6F8C1C53D0>

# %% [markdown]
# Above are the results of implementing the pytorch model,P2 in keras. The test accuracy is 98.55%, while the test loss is 0.042. The training accuracy of final epoch is 98.81%, while the training loss is 0.0402. Compared to model K2, the hyperparameters and network layers are modified in order to implement the same pytorch model in keras.
#
# The model K2 is less time-consuming than K1 and P1, and performs as well as P1. Both the training accuracy and the test accuracy is high. From the plots of model accuracy and model loss, the training accuracy gradually increases until it stabilizes and the loss gradually decreases until it stabilizes. The model K2 does not underfit or overfit. Compared to the models implemented in pytorch, K2 has fewer epochs but still has a high accuracy. Moreover, after the first epoch, the loss in keras is lower than the loss in pytorch. And the confusion matrix vividly shows that there's no concentrated errors.

# %% [markdown]
# #### Model P2

# %% [markdown]
# EPOCH [1/6]. Running Loss: 186.08 Progress: 33.33 %
# EPOCH [1/6]. Running Loss: 245.1 Progress: 66.67 %
# EPOCH [1/6]. Running Loss: 283.13 Progress: 100.0 %
# Train Avg. Loss: [0.1946] Acc: 0.8945 on 60000.0 images
# Validating...
# Val Avg. Loss: [0.1911] Acc: 0.9657 on 10000.0 images
#
# EPOCH [2/6]. Running Loss: 28.32 Progress: 33.33 %
# EPOCH [2/6]. Running Loss: 51.98 Progress: 66.67 %
# EPOCH [2/6]. Running Loss: 73.33 Progress: 100.0 %
# Train Avg. Loss: [0.0862] Acc: 0.9695 on 60000.0 images
# Validating...
# Val Avg. Loss: [0.0982] Acc: 0.9778 on 10000.0 images
#
# EPOCH [3/6]. Running Loss: 17.66 Progress: 33.33 %
# EPOCH [3/6]. Running Loss: 34.57 Progress: 66.67 %
# EPOCH [3/6]. Running Loss: 49.61 Progress: 100.0 %
# Train Avg. Loss: [0.0721] Acc: 0.9782 on 60000.0 images
# Validating...
# Val Avg. Loss: [0.0748] Acc: 0.981 on 10000.0 images
#
# EPOCH [4/6]. Running Loss: 13.49 Progress: 33.33 %
# EPOCH [4/6]. Running Loss: 26.46 Progress: 66.67 %
# EPOCH [4/6]. Running Loss: 39.03 Progress: 100.0 %
# Train Avg. Loss: [0.0214] Acc: 0.9824 on 60000.0 images
# Validating...
# Val Avg. Loss: [0.0572] Acc: 0.9832 on 10000.0 images
#
# EPOCH [5/6]. Running Loss: 11.1 Progress: 33.33 %
# EPOCH [5/6]. Running Loss: 22.07 Progress: 66.67 %
# EPOCH [5/6]. Running Loss: 32.42 Progress: 100.0 %
# Train Avg. Loss: [0.0797] Acc: 0.9852 on 60000.0 images
# Validating...
# Val Avg. Loss: [0.0444] Acc: 0.985 on 10000.0 images
#
# EPOCH [6/6]. Running Loss: 10.18 Progress: 33.33 %
# EPOCH [6/6]. Running Loss: 18.93 Progress: 66.67 %
# EPOCH [6/6]. Running Loss: 28.16 Progress: 100.0 %
# Train Avg. Loss: [0.0389] Acc: 0.9872 on 60000.0 images
# Validating...
# Val Avg. Loss: [0.0243] Acc: 0.9848 on 10000.0 images
#
# Time Elapsed: 905.050688 seconds
# Test Accuracy of the model on the 10000 test images: 98.48 %
# Time Elapsed: 8.165139 seconds

# %%
im = Image.open("P2-2.png")
print("Graphs of P2 Model ")
display(im)
im = Image.open("P2-4.png")
display(im)
# Out:
# Graphs of P2 Model
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=680x336 at 0x7F6F8C1CE590>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=323x280 at 0x7F6F8C1CED50>

# %% [markdown]
# Above are the results of the demonstration notebook ModelP2-Ptorch without modification. The test accuracy is 98.48%, while the test loss is 0.0243. The training accuracy of final epoch is 98.72%, while the training loss is 0.0389.
#
# The model P2 takes the least amount of time and performs well. Both the training accuracy and the test accuracy is high. From the plots of model accuracy and model loss, the training accuracy gradually increases until it stabilizes while the loss fluctuates up and down. The model P2 does not overfit, so if there are more epochs, it may be trained tp perform better. Similar to K2, after the first epoch, the loss in keras is lower than the loss in pytorch. And the confusion matrix vividly shows that there's no concentrated errors.

# %% [markdown]
# ## 2. New Model Design

# %%
#show the new model here
# Model
# Convolutional neural network (two convolutional layers)
class ConvNet(nn.Module):
    def __init__(self, num_classes=10):
        super(ConvNet, self).__init__()
        self.layer1 = nn.Sequential(
            ),
            #change channel numbers
            nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
            )
        self.layer2 = nn.Sequential(
            ),
            #change channel numbers
            nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        self.fc1 = nn.Sequential(
            nn.Linear(7*7*64, 512),
            nn.ReLU()
            )
        # add another layer
        self.fc = nn.Linear(512, num_classes)
        # add a dropout
        self.drop_out = nn.Dropout(p=0.4)
        # add a fatten
        self.flat = nn.Flatten()
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out) 
        out = self.flat(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc1(out)
        out = self.drop_out(out)
        out = self.fc(out)
        return out

model = ConvNet(num_classes).to(device)

# %% [markdown]
# Because it runs too slow in jupyter, I chose to use colab to complete the section2 experiments. The Accuracy and Loss results for the same ipynb using the GPU are similar to those using the CPU for the same size, but the consumption time is much shorter. In addition, the running time can also be shortened by modifying the size of hyperparameters such as learning rate.
#
# The test accuracy of the original pytorch model running in colab is 98.59%, which performs well. Now, I will experiment in four steps to optimize the model.

# %% [markdown]
# ##### 1. Change the input size or number of the neurons
# <table>
#     <tr><th> Model</th><th>Test<br>Accuracy(%)</th><th>Test Loss</th><th>Training<br>Accuracy(%)</th><th>Training Loss</th></tr>
#     <tr><td>1-16-32(original)</td><td>98.59</td><td>0.0257</td><td>98.69</td><td>0.0585</td></tr>
#     <tr><td>1-32-64</td><td>98.99</td><td>0.0122</td><td>99.17</td><td>0.0369</td></tr>
#     <tr><td>1-64-128</td><td>98.98</td><td>0.0232</td><td>99.49</td><td>0.0664</td></tr>
#     </table>

# %%
im = Image.open("sec2-1.png")
print("Graphs of 1-32-64 model ")
display(im)
# Out:
# Graphs of 1-32-64 model
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=674x336 at 0x7F6F8C1B6D10>

# %% [markdown]
# The first step is to change the input and output size of the two convolutional layers. The original model has 1 to 16 channels in the first convolutional layer and 16 to 32 channels in the second convolutional layer. I tried the model with 1-32-64 channel and 1-64-128 channel. The test accuracy of both two new models has improved. According to the plots of two models, the model with 1-64-128 channel is overfitting a little and more time-consuming. So I chose the 1-32-64 one, which has the similar test accuracy of the model with 1-64-128 channel.

# %% [markdown]
# ##### 2. Add another layer of Dense layer
# <table>
#     <tr><th> Model</th><th>Test<br>Accuracy(%)</th><th>Test Loss</th><th>Training<br>Accuracy(%)</th><th>Training Loss</th></tr>
#     <tr><td>Liner 128</td><td>99.07</td><td>0.0273</td><td>99.34</td><td>0.0337</td></tr>
#     <tr><td>Liner 256</td><td>99.09</td><td>0.0075</td><td>99.42</td><td>0.0249</td></tr>
#     <tr><td>Liner 512</td><td>99.12</td><td>0.0221</td><td>99.48</td><td>0.0075</td></tr>
#     </table>

# %%
im = Image.open("sec2-2.png")
print("Graphs of adding dense layer of Liner512 ")
display(im)
# Out:
# Graphs of adding dense layer of Liner512
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=674x336 at 0x7F6F8C1CDC50>

# %% [markdown]
# Secondly, another layer of dense layer is added to experiment. Through the dense layer, I tested the liner function with different number of the output classes. From Liner 128 to Liner 512 model, both of the test and training accuracy increase. The model with the liner function 512 performs the best and there's almost no overfit (when incresing the function output to 600 classes, there's a overfit in epoch5.). As a result, the improved model now has two convolutional layers with 1-32-64 channels and an added dense layer with Liner 512 function.

# %% [markdown]
# ##### 3. Add a dropout
# <table>
#     <tr><th> Model</th><th>Test<br>Accuracy(%)</th><th>Test Loss</th><th>Training<br>Accuracy(%)</th><th>Training Loss</th></tr>
#     <tr><td>p = 0.2</td><td>99.0</td><td>0.01</td><td>99.4</td><td>0.0036</td></tr>
#     <tr><td>p = 0.3</td><td>98.88</td><td>0.0025</td><td>99.27</td><td>0.0034</td></tr>
#     <tr><td>p = 0.4</td><td>99.22</td><td>0.0067</td><td>99.23</td><td>0.0232</td></tr>
#     <tr><td>p = 0.5</td><td>99.2</td><td>0.0076</td><td>99.09</td><td>0.0053</td></tr>
#     <tr><td>p = 0.6</td><td>99.11</td><td>0.0038</td><td>98.93</td><td>0.0357</td></tr>
#     </table>

# %%
im = Image.open("sec2-3.png")
print("Graphs of adding a dropout function with p=0.4 ")
display(im)
# Out:
# Graphs of adding a dropout function with p=0.4
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=674x336 at 0x7F6F8C165110>

# %% [markdown]
# Thirdly, because there's a little overfit in the current model, the dropout function is added. Five values of parameter p are tested. When p = 0.4, the test accuracy is the highest. With the help of dropout function, the test loss becomes smaller.

# %% [markdown]
# ##### 4. Add a flatten
# <table>
# <tr><th> Model</th><th>Test<br>Accuracy(%)</th><th>Test Loss</th><th>Training<br>Accuracy(%)</th><th>Training Loss</th></tr>
#     <tr><td>original</td><td>98.59</td><td>0.0257</td><td>98.69</td><td>0.0585</td></tr>
#     <tr><td>final</td><td>99.24</td><td>0.0116</td><td>99.26</td><td>0.0084</td></tr>
#   </table>

# %%
im = Image.open("sec2-4.png")
print("Graphs of the final modified model ")
display(im)
# Out:
# Graphs of the final modified model
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=674x336 at 0x7F6F8C165590>

# %% [markdown]
# Finally, the flatten part is added to improve the accuracy. Through modification, running in colab, the best test accuracy is 99.24 and the test loss is 0.0116, while the training accuracy is 99.26 and the training loss is 0.0084. The detailed results are shown as following.

# %% [markdown]
# EPOCH [1/6]. Running Loss: 88.0 Progress: 33.33 %
# EPOCH [1/6]. Running Loss: 113.94 Progress: 66.67 %
# EPOCH [1/6]. Running Loss: 132.34 Progress: 100.0 %
# Train Avg. Loss: [0.0703] Acc: 0.9407 on 60000.0 images
# Validating...
# Val Avg. Loss: [0.0696] Acc: 0.9806 on 10000.0 images
#
# EPOCH [2/6]. Running Loss: 14.37 Progress: 33.33 %
# EPOCH [2/6]. Running Loss: 27.21 Progress: 66.67 %
# EPOCH [2/6]. Running Loss: 38.34 Progress: 100.0 %
# Train Avg. Loss: [0.0737] Acc: 0.9805 on 60000.0 images
# Validating...
# Val Avg. Loss: [0.0223] Acc: 0.9876 on 10000.0 images
#
# EPOCH [3/6]. Running Loss: 9.21 Progress: 33.33 %
# EPOCH [3/6]. Running Loss: 17.91 Progress: 66.67 %
# EPOCH [3/6]. Running Loss: 27.21 Progress: 100.0 %
# Train Avg. Loss: [0.0157] Acc: 0.9862 on 60000.0 images
# Validating...
# Val Avg. Loss: [0.0161] Acc: 0.9897 on 10000.0 images
#
# EPOCH [4/6]. Running Loss: 7.48 Progress: 33.33 %
# EPOCH [4/6]. Running Loss: 14.93 Progress: 66.67 %
# EPOCH [4/6]. Running Loss: 21.96 Progress: 100.0 %
# Train Avg. Loss: [0.0111] Acc: 0.9889 on 60000.0 images
# Validating...
# Val Avg. Loss: [0.0104] Acc: 0.9914 on 10000.0 images
#
# EPOCH [5/6]. Running Loss: 5.63 Progress: 33.33 %
# EPOCH [5/6]. Running Loss: 11.16 Progress: 66.67 %
# EPOCH [5/6]. Running Loss: 17.19 Progress: 100.0 %
# Train Avg. Loss: [0.0249] Acc: 0.9911 on 60000.0 images
# Validating...
# Val Avg. Loss: [0.0053] Acc: 0.9891 on 10000.0 images
#
# EPOCH [6/6]. Running Loss: 4.43 Progress: 33.33 %
# EPOCH [6/6]. Running Loss: 9.78 Progress: 66.67 %
# EPOCH [6/6]. Running Loss: 14.79 Progress: 100.0 %
# Train Avg. Loss: [0.0084] Acc: 0.9926 on 60000.0 images
# Validating...
# Val Avg. Loss: [0.0116] Acc: 0.9924 on 10000.0 images
#
# Time Elapsed: 775.531765 seconds
# Test Accuracy of the model on the 10000 test images: 99.24 %
# Time Elapsed: 7.332497 seconds

# %%
im = Image.open("sec2-5.png")
display(im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=323x280 at 0x7F6F8C0F6210>

# %% [markdown]
# ## 3. Results on own Data

# %% [markdown]
# EPOCH [1/6]. Running Loss: 189.3 Progress: 33.33 %
# EPOCH [1/6]. Running Loss: 243.98 Progress: 66.67 %
# EPOCH [1/6]. Running Loss: 279.89 Progress: 100.0 %
# Train Avg. Loss: [0.1127] Acc: 0.894 on 60000.0 images
# Validating...
# Val Avg. Loss: [2.186] Acc: 0.7166666666666667 on 60.0 images
#
# EPOCH [2/6]. Running Loss: 26.17 Progress: 33.33 %
# EPOCH [2/6]. Running Loss: 48.75 Progress: 66.67 %
# EPOCH [2/6]. Running Loss: 68.59 Progress: 100.0 %
# Train Avg. Loss: [0.0793] Acc: 0.9712 on 60000.0 images
# Validating...
# Val Avg. Loss: [2.3307] Acc: 0.7666666666666667 on 60.0 images
#
# EPOCH [3/6]. Running Loss: 17.4 Progress: 33.33 %
# EPOCH [3/6]. Running Loss: 32.37 Progress: 66.67 %
# EPOCH [3/6]. Running Loss: 46.47 Progress: 100.0 %
# Train Avg. Loss: [0.0716] Acc: 0.9795 on 60000.0 images
# Validating...
# Val Avg. Loss: [2.4451] Acc: 0.7666666666666667 on 60.0 images
#
# EPOCH [4/6]. Running Loss: 12.48 Progress: 33.33 %
# EPOCH [4/6]. Running Loss: 24.51 Progress: 66.67 %
# EPOCH [4/6]. Running Loss: 36.64 Progress: 100.0 %
# Train Avg. Loss: [0.0457] Acc: 0.9832 on 60000.0 images
# Validating...
# Val Avg. Loss: [2.5103] Acc: 0.7666666666666667 on 60.0 images
#
# EPOCH [5/6]. Running Loss: 10.14 Progress: 33.33 %
# EPOCH [5/6]. Running Loss: 20.81 Progress: 66.67 %
# EPOCH [5/6]. Running Loss: 30.59 Progress: 100.0 %
# Train Avg. Loss: [0.0315] Acc: 0.986 on 60000.0 images
# Validating...
# Val Avg. Loss: [2.5601] Acc: 0.7666666666666667 on 60.0 images
#
# EPOCH [6/6]. Running Loss: 8.83 Progress: 33.33 %
# EPOCH [6/6]. Running Loss: 18.12 Progress: 66.67 %
# EPOCH [6/6]. Running Loss: 26.35 Progress: 100.0 %
# Train Avg. Loss: [0.0206] Acc: 0.988 on 60000.0 images
# Validating...
# Val Avg. Loss: [2.6667] Acc: 0.7666666666666667 on 60.0 images
#
# Time Elapsed: 290.841196 seconds
# Test Accuracy of the model on the 60 test images: 76.66666666666667 %
# Time Elapsed: 0.043089 seconds

# %%
im = Image.open("5-1.png")
print("Graphs on idata")
display(im)
im = Image.open("5-2.png")
display(im)
# Out:
# Graphs on idata
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=668x336 at 0x7F6F8C1C5910>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=304x280 at 0x7F6F8C1CE750>

# %% [markdown]
# When applying my own dataset on the pytorch model, there are two points. First, I choose to use idata2 from lab7 because it is more similar to the MINIST dataset and it is reasonable to compare. Second, I changed the label of the non-numeric characters in the dataset to 10 and changed the class_num of the model to 11. It helps the algorithm go smoothly.
#
# Above are the results of testing on idata2. The test accuracy is 76.67%, while the test loss is 2.6667. The training accuracy of final epoch is 98.2%, while the training loss is 0.0206. According to the plots and epochs above, there's no underfitting. But the test loss increases as more epochs, so overfitting may exist. From the confusion matrix, most of errors appear in non-numeric characters. Other than that, the number 1 has the most errors. The performance of CNN is better than the algorithms in lab7.

# %% [markdown]
# ## 4. Summary
# ### Comparison of approaches
#
# <table>
#     <tr><th> Model</th><th>Accuracy(%)</th><th>Test Loss</th><th>Training<br>Time</th><th>Epochs</th><th>Testing<br>Time</th><th>Training<br>Accuracy(%)</th><th></th></tr>
#     <tr><td>Keras Tutorial</td><td>99.15</td><td>0.0265</td><td>-</td><td>12</td><td>-</td><td>-</td><td></td></tr>
# <tr><td>ModelK1</td><td>82.92</td><td>0.7528</td><td>6974.98</td><td>12</td><td>63.89</td><td>69.69</td><td></td></tr>
# <tr><td>ModelP1</td><td>98.81</td><td>1.4612</td><td>2298.04</td><td>12</td><td>3.69</td><td>98.28</td><td></td></tr>
# <tr><td>ModelK2</td><td>98.55</td><td>0.0419</td><td>1647.64</td><td>6</td><td>3.83</td><td>98.81</td><td></td></tr>
# <tr><td>ModelP2</td><td>98.48</td><td>0.0243</td><td>905.05</td><td>6</td><td>8.16</td><td>98.72</td><td></td></tr>
# <tr><td>Custom Model</td><td>99.2</td><td>0.0096</td><td>2656.31</td><td>6</td><td>18.28</td><td>99.2</td><td></td></tr>
# <tr><td>Custom data</td><td>76.67</td><td>2.6667</td><td>290.84</td><td>6</td><td>0.043</td><td>98.8</td><td></td></tr>
#     </table>
#
# ### Discusssion
#
#
# To ensure the validity of the comparison, all results are run in a jupyter environment.
# #### 1.  The loss of the model in keras is always lower than the one in pytorch.
#
# #### 2.  The model in keras is more time-consuming than the one in pytorch.
#
# #### 3. A high level of training accuracy does not guarantee a high level of test accuracy.
