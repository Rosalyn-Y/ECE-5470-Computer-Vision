# %%
from v4 import vd
vd.dispsvx ('testim3.vx', capt='small image display from a file')
# Out:
# small image display from a file
# <scaled size: (10 x 10) >

# %%
! cclabel.py if=testim3.vx of=testim3.mx
vd.dispsvx ('testim3.mx', capt='mx')
# Out:
# mx
# <scaled size: (10 x 10) >

# %%
vd.dispsvx ('sec5_1.vx', capt='small image display from a file')
# Out:
# small image display from a file
# <scaled size: (8 x 10) >

# %%
! cclabel.py if=sec5_1.vx of=sec5_1.mx
vd.dispsvx ('sec5_1.mx', capt='mx')
# Out:
# mx
# <scaled size: (8 x 10) >

# %%
vd.dispsvx ('sec5_2.vx', capt='small image display from a file')
# Out:
# small image display from a file
# <scaled size: (7 x 9) >

# %%
! cclabel.py if=sec5_2.vx of=sec5_2.mx
vd.dispsvx ('sec5_2.mx', capt='mx')
# Out:
# mx
# <scaled size: (7 x 9) >

# %%
vd.dispsvx ('sec5_3.vx', capt='small image display from a file')
# Out:
# small image display from a file
# <scaled size: (7 x 9) >

# %%
! cclabel.py if=sec5_3.vx of=sec5_3.mx
vd.dispsvx ('sec5_3.mx', capt='mx')
# Out:
# mx
# <scaled size: (7 x 9) >

# %%
vd.dispmvx ('im3.vx')
# Out:
# small image display from a file
# <scaled size: (256 x 256) >

# %%
! cclabel.py if=im3.vx of=im3.mx
vd.dispmvx ('im3.mx', capt='mx')
# Out:
# mx
# <scaled size: (256 x 256) >
