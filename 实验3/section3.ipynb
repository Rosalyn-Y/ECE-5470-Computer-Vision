# %%
import numpy as np
from v4 import vx
from v4 import vd

# %%
exec(vx.vxsh('vits small.vx of=small_vits.vx'))
vd.dispvx('small.vx')
vd.dispvx('small_vits.vx',size=0.75,  capt='result of vits on mp.vx')
# Out:
# <PIL.Image.Image image mode=L size=280x218 at 0x7F7AE07F7890>
# <PIL.Image.Image image mode=L size=280x218 at 0x7F7AE07F7C90>
# result of vits on mp.vx

# %%
exec(vx.vxsh('vplot -h small.vx -rpng of=smallh.png'))
vd.dispvx('smallh.png')
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F7AE058E390>

# %%
thresh= 128.47093023255815

# %%
exec(vx.vxsh('vits mp.vx of=mp_vits.vx'))
vd.dispmvx('mp.vx','mp_vits.vx',size=0.75,  capt='result of vits on mp.vx')
# Out:
# result of vits on mp.vx
# <scaled size: (512 x 512) (512 x 512) >

# %%
exec(vx.vxsh('vits nb.vx of=nb_vits.vx'))
vd.dispmvx('nb.vx','nb_vits.vx',size=0.75,  capt='result of vits on mp.vx')
# Out:
# result of vits on mp.vx
# <scaled size: (64 x 128) (64 x 128) >

# %%
thresh= 128.24798237254407

# %%
exec(vx.vxsh('vits map of=map_vits.vx'))
vd.dispmvx('map','map_vits.vx',size=0.75,  capt='result of vits on mp.vx')
# Out:
# result of vits on mp.vx
# <scaled size: (512 x 512) (512 x 512) >

# %%
thresh= 135.31973436098335

# %%
exec(vx.vxsh('vits facsimile of=facsimile_vits.vx'))
vd.dispmvx('facsimile','facsimile_vits.vx',size=0.75,  capt='result of vits on mp.vx')
# Out:
# result of vits on mp.vx
# <scaled size: (256 x 256) (256 x 256) >

# %%
thresh= 179.1162725186727

# %%
exec(vx.vxsh('vits shtl.vx of=shtl_vits.vx'))
vd.dispmvx('shtl.vx','shtl_vits.vx',size=0.75,  capt='result of vits on shtl')
# Out:
# result of vits on shtl
# <scaled size: (256 x 256) (256 x 256) >

# %%
thresh= 122.46020696000528
